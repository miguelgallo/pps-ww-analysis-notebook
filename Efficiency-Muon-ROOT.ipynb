# %%
import numpy as np
import ROOT

# file_eff_MuID = ROOT.TFile.Open( "efficiencies/muon/RunBCDEF_SF_MuID.root", "READ" )
# file_eff_MuID = ROOT.TFile.Open( "efficiencies/muon/2017/RunBCDEF_SF_ID.root", "READ" )
# file_eff_syst_MuID = ROOT.TFile.Open( "efficiencies/muon/2017/RunBCDEF_SF_ID_syst.root", "READ" )
# file_eff_syst_MuID = ROOT.TFile.Open( "efficiencies/muon/2018/RunABCD_SF_ID.root", "READ" )
file_eff_MuID = ROOT.TFile.Open( "efficiencies/muon/id/2018/Efficiencies_muon_generalTracks_Z_Run2018_UL_ID.root", "READ" )
file_eff_MuTRG = ROOT.TFile.Open( "efficiencies/muon/trigger/2018/Efficiencies_muon_generalTracks_Z_Run2018_UL_SingleMuonTriggers.root", "READ" )
# file_eff_MuID = ROOT.TFile.Open( "efficiencies/muon/id/2017/Efficiencies_muon_generalTracks_Z_Run2017_UL_ID.root", "READ" )
# file_eff_MuTRG = ROOT.TFile.Open( "efficiencies/muon/trigger/2017/Efficiencies_muon_generalTracks_Z_Run2017_UL_SingleMuonTriggers.root", "READ" )

# histName = "NUM_TightID_DEN_genTracks_pt_abseta"
# histName = "NUM_TightID_DEN_TrackerMuons_pt_abseta"
histName_MuID = "NUM_TrkHighPtID_DEN_TrackerMuons_abseta_pt"
histName_MuTRG = "NUM_IsoMu24_DEN_CutBasedIdTight_and_PFIsoTight_abseta_pt"
# histName_MuTRG = "NUM_IsoMu27_DEN_CutBasedIdTight_and_PFIsoTight_abseta_pt"
# Out:
# Welcome to JupyROOT 6.26/08

# %%
file_eff_MuID.ls()
# Out:
# TFile**		efficiencies/muon/id/2018/Efficiencies_muon_generalTracks_Z_Run2018_UL_ID.root
#  TFile*		efficiencies/muon/id/2018/Efficiencies_muon_generalTracks_Z_Run2018_UL_ID.root
#   KEY: TH2F	NUM_HighPtID_DEN_TrackerMuons_abseta_pt;1	NUM_HighPtID_DEN_TrackerMuons_abseta_pt
#   KEY: TH2F	NUM_HighPtID_DEN_TrackerMuons_abseta_pt_stat;1	NUM_HighPtID_DEN_TrackerMuons_abseta_pt
#   KEY: TH2F	NUM_HighPtID_DEN_TrackerMuons_abseta_pt_syst;1	NUM_HighPtID_DEN_TrackerMuons_abseta_pt
#   KEY: TH2F	NUM_HighPtID_DEN_TrackerMuons_abseta_pt_efficiencyData;1	NUM_HighPtID_DEN_TrackerMuons_abseta_pt
#   KEY: TH2F	NUM_HighPtID_DEN_TrackerMuons_abseta_pt_efficiencyData_stat;1	NUM_HighPtID_DEN_TrackerMuons_abseta_pt
#   KEY: TH2F	NUM_HighPtID_DEN_TrackerMuons_abseta_pt_efficiencyData_syst;1	NUM_HighPtID_DEN_TrackerMuons_abseta_pt
#   KEY: TH2F	NUM_HighPtID_DEN_TrackerMuons_abseta_pt_efficiencyMC;1	NUM_HighPtID_DEN_TrackerMuons_abseta_pt
# ...

# %%
file_eff_MuTRG.ls()
# Out:
# TFile**		efficiencies/muon/trigger/2018/Efficiencies_muon_generalTracks_Z_Run2018_UL_SingleMuonTriggers.root
#  TFile*		efficiencies/muon/trigger/2018/Efficiencies_muon_generalTracks_Z_Run2018_UL_SingleMuonTriggers.root
#   KEY: TH2F	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt;1	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt
#   KEY: TH2F	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt_stat;1	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt
#   KEY: TH2F	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt_syst;1	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt
#   KEY: TH2F	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt_efficiencyData;1	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt
#   KEY: TH2F	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt_efficiencyData_stat;1	NUM_IsoMu24_DEN_CutBasedIdMedium_and_PFIsoMedium_abseta_pt
# ...

# %%
# h_eff_MuID_2D = file_eff_MuID.Get( "NUM_TightID_DEN_genTracks_pt_abseta" )
# h_eff_MuID_2D = file_eff_syst_MuID.Get( "NUM_TightID_DEN_genTracks_pt_abseta" )
# h_eff_MuID_2D = file_eff_syst_MuID.Get( "NUM_TightID_DEN_genTracks_pt_abseta_stat" )
# h_eff_MuID_2D = file_eff_syst_MuID.Get( "NUM_TightID_DEN_genTracks_pt_abseta_syst" )
# h_eff_MuID_2D = file_eff_syst_MuID.Get( "NUM_TightID_DEN_TrackerMuons_pt_abseta" )
# h_eff_MuID_2D = file_eff_syst_MuID.Get( histName )
h_eff_MuID_2D = file_eff_MuID.Get( histName_MuID )
print ( h_eff_MuID_2D.GetYaxis().GetBinCenter( h_eff_MuID_2D.GetNbinsY() ) )
canvas = ROOT.TCanvas( "canvas" )
h_eff_MuID_2D.Draw()
canvas.Draw()
# Out:
# 90.0

# %%
# h_eff_stat_MuID_2D = file_eff_syst_MuID.Get( "NUM_TightID_DEN_genTracks_pt_abseta_stat" )
# h_eff_stat_MuID_2D = file_eff_syst_MuID.Get( "NUM_TightID_DEN_TrackerMuons_pt_abseta_stat" )
# h_eff_stat_MuID_2D = file_eff_syst_MuID.Get( histName + "_stat" )
h_eff_stat_MuID_2D = file_eff_MuID.Get( histName_MuID + "_stat" )
print ( h_eff_stat_MuID_2D.GetYaxis().GetBinCenter( h_eff_stat_MuID_2D.GetNbinsY() ) )
canvas = ROOT.TCanvas( "canvas" )
h_eff_stat_MuID_2D.Draw()
canvas.Draw()
# Out:
# 90.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
# h_eff_syst_MuID_2D = file_eff_syst_MuID.Get( "NUM_TightID_DEN_genTracks_pt_abseta_syst" )
# h_eff_syst_MuID_2D = file_eff_syst_MuID.Get( "NUM_TightID_DEN_TrackerMuons_pt_abseta_syst" )
# h_eff_syst_MuID_2D = file_eff_syst_MuID.Get( histName + "_syst" )
h_eff_syst_MuID_2D = file_eff_MuID.Get( histName_MuID + "_syst" )
print ( h_eff_syst_MuID_2D.GetYaxis().GetBinCenter( h_eff_syst_MuID_2D.GetNbinsY() ) )
canvas = ROOT.TCanvas( "canvas" )
h_eff_syst_MuID_2D.Draw()
canvas.Draw()
# Out:
# 90.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
# class MuonScaleFactor:
#     def __init__( self, histos ):
#         self.h2D_MuID = histos[ "MuID" ]
#     def __call__( self, pt, eta ):
#         sf_ = 1.
#         unc_ = 0.
# #         if pt < 120.:
# #             bin2D_ = self.h2D_MuID.FindBin( pt, np.abs( eta ) )
# #             sf_ = self.h2D_MuID.GetBinContent( bin2D_ )
# #             unc_ = self.h2D_MuID.GetBinError( bin2D_ )
#         if pt < 120.:
#             bin2D_ = self.h2D_MuID.FindBin( pt, np.abs( eta ) )
#             sf_ = self.h2D_MuID.GetBinContent( bin2D_ )
#             unc_ = self.h2D_MuID.GetBinError( bin2D_ )
#         else:
#             bin2D_ = self.h2D_MuID.FindBin( self.h2D_MuID.GetXaxis().GetBinCenter( self.h2D_MuID.GetNbinsX() ), np.abs( eta ) )
#             sf_ = self.h2D_MuID.GetBinContent( bin2D_ )
#             unc_ = self.h2D_MuID.GetBinError( bin2D_ )
#         return ( sf_, unc_ )

# %%
class MuonIDScaleFactor:
    def __init__( self, histos, debug=False ):
        self.debug_ = debug
        self.h2D_MuID = histos[ "MuID" ]
        self.h2D_MuID_stat = histos[ "MuID_stat" ]
        self.h2D_MuID_syst = histos[ "MuID_syst" ]
        self.ptmax_ = 120.
    def __call__( self, eta, pt ):
        sf_ = 1.
        unc_ = 0.
        bin2D_ = None
        bin2D_stat_ = None
        bin2D_syst_ = None
        if pt < self.ptmax_:
            bin2D_ = self.h2D_MuID.FindBin( np.abs( eta ), pt )
            bin2D_stat_ = self.h2D_MuID_stat.FindBin( np.abs( eta ), pt )
            bin2D_syst_ = self.h2D_MuID_syst.FindBin( np.abs( eta ), pt )
        else:
            bin2D_ = self.h2D_MuID.FindBin(
                np.abs( eta ),
                self.h2D_MuID.GetYaxis().GetBinCenter( self.h2D_MuID.GetNbinsY() ) )
            bin2D_stat_ = self.h2D_MuID_stat.FindBin(
                np.abs( eta ),
                self.h2D_MuID_stat.GetYaxis().GetBinCenter( self.h2D_MuID_stat.GetNbinsY() ) )
            bin2D_syst_ = self.h2D_MuID_syst.FindBin(
                np.abs( eta ),
                self.h2D_MuID_syst.GetYaxis().GetBinCenter( self.h2D_MuID_syst.GetNbinsY() ) )
        sf_ = self.h2D_MuID.GetBinContent( bin2D_ )
        err_stat_ = self.h2D_MuID_stat.GetBinError( bin2D_stat_ )
        err_syst_ = self.h2D_MuID_syst.GetBinError( bin2D_syst_ )
        unc_ = np.sqrt( err_stat_ ** 2 + err_syst_ ** 2 )
        if self.debug_:
            print ( bin2D_, bin2D_stat_, bin2D_syst_, sf_, err_stat_, err_syst_, unc_ )
        return ( sf_, unc_ )

# %%
# muon_scale_factor_ = MuonScaleFactor( histos = { "MuID": h_eff_MuID_2D } )
# muon_scale_factor_ = MuonScaleFactor( histos = { "MuID": h_eff_syst_MuID_2D } )
# muon_scale_factor_ = MuonScaleFactor( histos = { "MuID": h_eff_MuID_2D, "MuID_stat": h_eff_stat_MuID_2D, "MuID_syst": h_eff_syst_MuID_2D }, debug=True )
muon_scale_factor_ = MuonIDScaleFactor( histos = { "MuID": h_eff_MuID_2D, "MuID_stat": h_eff_stat_MuID_2D, "MuID_syst": h_eff_syst_MuID_2D }, debug=True )

# %%
muon_scale_factor_( 1.0, 150. )
# Out:
# 44 44 44 0.9957872033119202 0.0004413790866326841 0.0003590550013489084 0.0005689780242771834
# (0.9957872033119202, 0.0005689780242771834)

# %% [markdown]
# ### Trigger

# %%
h_eff_MuTRG_2D = file_eff_MuTRG.Get( histName_MuTRG )
print ( h_eff_MuTRG_2D.GetYaxis().GetBinCenter( h_eff_MuTRG_2D.GetNbinsY() ) )
canvas = ROOT.TCanvas( "canvas" )
h_eff_MuTRG_2D.Draw()
canvas.Draw()
# Out:
# 160.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
h_eff_stat_MuTRG_2D = file_eff_MuTRG.Get( histName_MuTRG + "_stat" )
print ( h_eff_stat_MuTRG_2D.GetYaxis().GetBinCenter( h_eff_stat_MuTRG_2D.GetNbinsY() ) )
canvas = ROOT.TCanvas( "canvas" )
h_eff_stat_MuTRG_2D.Draw()
canvas.Draw()
# Out:
# 160.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
h_eff_syst_MuTRG_2D = file_eff_MuTRG.Get( histName_MuTRG + "_syst" )
print ( h_eff_syst_MuTRG_2D.GetYaxis().GetBinCenter( h_eff_syst_MuTRG_2D.GetNbinsY() ) )
canvas = ROOT.TCanvas( "canvas" )
h_eff_syst_MuTRG_2D.Draw()
canvas.Draw()
# Out:
# 160.0
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: canvas

# %%
class MuonTRGScaleFactor:
    def __init__( self, histos, debug=False ):
        self.debug_ = debug
        self.h2D_MuTRG = histos[ "MuTRG" ]
        self.h2D_MuTRG_stat = histos[ "MuTRG_stat" ]
        self.h2D_MuTRG_syst = histos[ "MuTRG_syst" ]
        self.ptmax_ = 200.
    def __call__( self, eta, pt ):
        sf_ = 1.
        unc_ = 0.
        bin2D_ = None
        bin2D_stat_ = None
        bin2D_syst_ = None
        if pt < self.ptmax_:
            bin2D_ = self.h2D_MuTRG.FindBin( np.abs( eta ), pt )
            bin2D_stat_ = self.h2D_MuTRG_stat.FindBin( np.abs( eta ), pt )
            bin2D_syst_ = self.h2D_MuTRG_syst.FindBin( np.abs( eta ), pt )
        else:
            bin2D_ = self.h2D_MuTRG.FindBin(
                np.abs( eta ),
                self.h2D_MuTRG.GetYaxis().GetBinCenter( self.h2D_MuTRG.GetNbinsY() ) )
            bin2D_stat_ = self.h2D_MuTRG_stat.FindBin(
                np.abs( eta ),
                self.h2D_MuTRG_stat.GetYaxis().GetBinCenter( self.h2D_MuTRG_stat.GetNbinsY() ) )
            bin2D_syst_ = self.h2D_MuTRG_syst.FindBin(
                np.abs( eta ),
                self.h2D_MuTRG_syst.GetYaxis().GetBinCenter( self.h2D_MuTRG_syst.GetNbinsY() ) )
        sf_ = self.h2D_MuTRG.GetBinContent( bin2D_ )
        err_stat_ = self.h2D_MuTRG_stat.GetBinError( bin2D_stat_ )
        err_syst_ = self.h2D_MuTRG_syst.GetBinError( bin2D_syst_ )
        unc_ = np.sqrt( err_stat_ ** 2 + err_syst_ ** 2 )
        if self.debug_:
            print ( bin2D_, bin2D_stat_, bin2D_syst_, sf_, err_stat_, err_syst_, unc_ )
        return ( sf_, unc_ )

# %%
muon_scale_factor_TRG_ = MuonTRGScaleFactor( histos = { "MuTRG": h_eff_MuTRG_2D, "MuTRG_stat": h_eff_stat_MuTRG_2D, "MuTRG_syst": h_eff_syst_MuTRG_2D }, debug=True )

# %%
muon_scale_factor_TRG_( 2., 250. )
# Out:
# 39 39 39 1.0041680335998535 0.0030575275738809467 0.0017296864887474243 0.003512874921541856
# (1.0041680335998535, 0.003512874921541856)
