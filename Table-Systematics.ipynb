# %%
import sys
# sys.path.insert(0,'/eos/home-a/antoniov/SWAN_projects/env/uproot4/lib/python3.7/site-packages')
# sys.path.insert(0,'/eos/home-a/antoniov/SWAN_projects/env/uproot/lib/python3.8/site-packages')
# sys.path.insert(0,'/eos/home-a/antoniov/SWAN_projects/env/uproot-py39/lib/python3.9/site-packages')
print ( sys.path )

import numpy as np
import pandas as pd
import h5py
# Out:
# ['/cvmfs/sft.cern.ch/lcg/releases/condor/8.9.11-50a33/x86_64-centos7-gcc11-opt/lib/python3', '/cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/itk', '/cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/python', '/cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib', '', '/cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages', '/srv/dask/lib', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python39.zip', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/lib-dynload', '/eos/user/m/malvesga/.local/lib/python3.9/site-packages', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.12-9a1bc/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages', '/cvmfs/sft.cern.ch/lcg/views/LCG_105_swan/x86_64-centos7-gcc11-opt/l
# ...

# %%
lepton_type = 'muon'
# lepton_type = 'electron'

# data_sample = '2017'
data_sample = '2018'

norm_to_1fb = False
# norm_to_1fb = True

run_dissociative_signal = True
# run_dissociative_signal = False

upper_mass_ratio_cut = True
# upper_mass_ratio_cut = False

# alpha = 'a0w'
alpha = 'aCw'

# %%
# file_str_ = "datacards_norm-F_diss-F_mass-F/"
# if data_sample == '2017':
#     if lepton_type == 'muon':
#         file_path_ = file_str_+"table_systematics-2017-muon.h5"
#     elif lepton_type == 'electron':
#         file_path_ = file_str_+"table_systematics-2017-electron.h5"
# elif data_sample == '2018':
#     if lepton_type == 'muon':
#         file_path_ = file_str_+"table_systematics-"+alpha+"-2018-muon.h5"
#     elif lepton_type == 'electron':
#         file_path_ = file_str_+"table_systematics-"+alpha+"-2018-electron.h5"
file_path_ = ""
file_str_ = "datacards_norm-F_diss-T_mass-T_lim-nom/table_systematics"
if norm_to_1fb:
    file_str_ += "-norm_to_1fb"
if upper_mass_ratio_cut:
    file_str_ += "-mass_cut"
if run_dissociative_signal:
    file_str_ += "-diss"
if data_sample == '2017':
    if lepton_type == 'muon':
        file_path_ = file_str_ + "-2017-muon" + ".h5"
    elif lepton_type == 'electron':
        file_path_ = file_str_ + "-2017-electron" + ".h5"
elif data_sample == '2018':
    if lepton_type == 'muon':
        file_path_ = file_str_ + "-"+alpha+"-2018-muon" + ".h5"
    elif lepton_type == 'electron':
        file_path_ = file_str_ + "-"+alpha+"-2018-electron" + ".h5"
        
df_sum_weights = None
with pd.HDFStore( file_path_, 'r' ) as store_:
    print ( list( store_ ) )
    df_sum_weights = store_[ "table_systematics" ]
# Out:
# ['/table_systematics']

# %%
file_str_ = "datacards_norm-F_diss-T_mass-T_lim-sup/table_systematics"
if norm_to_1fb:
    file_str_ += "-norm_to_1fb"
if upper_mass_ratio_cut:
    file_str_ += "-mass_cut"
if run_dissociative_signal:
    file_str_ += "-diss"
if data_sample == '2017':
    if lepton_type == 'muon':
        file_path_ = file_str_ + "-2017-muon" + ".h5"
    elif lepton_type == 'electron':
        file_path_ = file_str_ + "-2017-electron" + ".h5"
elif data_sample == '2018':
    if lepton_type == 'muon':
        file_path_ = file_str_ + "-"+alpha+"-2018-muon" + ".h5"
    elif lepton_type == 'electron':
        file_path_ = file_str_ + "-"+alpha+"-2018-electron" + ".h5"
       
df_sum_weights_sup = None
with pd.HDFStore( file_path_, 'r' ) as store_:
    print ( list( store_ ) )
    df_sum_weights_sup = store_[ "table_systematics" ]
# Out:
# ['/table_systematics']

# %%
file_str_ = "datacards_norm-F_diss-T_mass-T_lim-inf/table_systematics"
if norm_to_1fb:
    file_str_ += "-norm_to_1fb"
if upper_mass_ratio_cut:
    file_str_ += "-mass_cut"
if run_dissociative_signal:
    file_str_ += "-diss"
if data_sample == '2017':
    if lepton_type == 'muon':
        file_path_ = file_str_ + "-2017-muon" + ".h5"
    elif lepton_type == 'electron':
        file_path_ = file_str_ + "-2017-electron" + ".h5"
elif data_sample == '2018':
    if lepton_type == 'muon':
        file_path_ = file_str_ + "-"+alpha+"-2018-muon" + ".h5"
    elif lepton_type == 'electron':
        file_path_ = file_str_ + "-"+alpha+"-2018-electron" + ".h5"
       
df_sum_weights_inf = None
with pd.HDFStore( file_path_, 'r' ) as store_:
    print ( list( store_ ) )
    df_sum_weights_inf = store_[ "table_systematics" ]
# Out:
# ['/table_systematics']

# %%
df_sum_weights
# Out:
#                            GGToWW-AQGC-2018-muon-ACW5e-7  \
# central                                         0.916316
# stat                                            0.092937
# syst_up_jes                                     0.041840
# syst_dw_jes                                    -0.041840
# syst_up_jer                                     0.010793
# syst_dw_jer                                    -0.010793
# syst_up_sf_muon_id                              0.000486
# syst_dw_sf_muon_id                             -0.000486
# syst_up_sf_muon_trigger                         0.001767
# syst_dw_sf_muon_trigger                        -0.001767
# syst_up_sf_prefiring                            0.001177
# syst_dw_sf_prefiring                           -0.001177
# syst_up_proton_scale_arm0                       0.027002
# syst_dw_proton_scale_arm0                      -0.090271
# syst_up_proton_scale_arm1                       0.065361
# ...

# %%
df_uncertainties_relative = None
if run_dissociative_signal:
    df_up = df_sum_weights_sup.iloc[ 0, : ] - df_sum_weights.iloc[ 0, : ]
    df_up['Background'] = -1.0 
    df_dw = df_sum_weights_inf.iloc[ 0, : ] - df_sum_weights.iloc[ 0, : ] 
    df_dw['Background'] = -1.0
    df1 = pd.DataFrame(df_up) 
    df1 = df1.transpose()
    df1 = df1.rename(index={'central': 'syst_up_diss'})
    df2 = pd.DataFrame(df_dw) 
    df2 = df2.transpose()
    df2 = df2.rename(index={'central': 'syst_dw_diss'})
    df3 = pd.concat([df1, df2], ignore_index = False) 
    display(df3)
    df_sum_weights = pd.concat([df_sum_weights, df3], ignore_index = False) 
df__ = df_sum_weights
df_uncertainties_relative = df__.iloc[ 1:, : ].where( ~( df__.iloc[ 1:, : ] != -1. ) , df__.iloc[ 1:, : ].divide( df__.iloc[ 0 ] ) )
# Out:
#               GGToWW-AQGC-2018-muon-ACW5e-7  GGToWW-AQGC-2018-muon-ACW1e-6  \
# syst_up_diss                       0.948873                       1.316287
# syst_dw_diss                      -0.186697                      -0.250493
#
#               GGToWW-AQGC-2018-muon-ACW2e-6  GGToWW-AQGC-2018-muon-ACW5e-6  \
# syst_up_diss                       2.883457                       8.102008
# syst_dw_diss                      -0.553757                      -1.560276
#
#               GGToWW-AQGC-2018-muon-ACW1e-5  GGToWW-AQGC-2018-muon-ACW2e-5  \
# syst_up_diss                      30.449074                     129.796585
# syst_dw_diss                      -5.851726                     -24.708195
#
#               Background
# syst_up_diss        -1.0
# syst_dw_diss        -1.0

# %%
df_sum_weights
# Out:
#                            GGToWW-AQGC-2018-muon-ACW5e-7  \
# central                                         0.916316
# stat                                            0.092937
# syst_up_jes                                     0.041840
# syst_dw_jes                                    -0.041840
# syst_up_jer                                     0.010793
# syst_dw_jer                                    -0.010793
# syst_up_sf_muon_id                              0.000486
# syst_dw_sf_muon_id                             -0.000486
# syst_up_sf_muon_trigger                         0.001767
# syst_dw_sf_muon_trigger                        -0.001767
# syst_up_sf_prefiring                            0.001177
# syst_dw_sf_prefiring                           -0.001177
# syst_up_proton_scale_arm0                       0.027002
# syst_dw_proton_scale_arm0                      -0.090271
# syst_up_proton_scale_arm1                       0.065361
# ...

# %%
df_sum_weights.index
# Out:
# Index(['central', 'stat', 'syst_up_jes', 'syst_dw_jes', 'syst_up_jer',
#        'syst_dw_jer', 'syst_up_sf_muon_id', 'syst_dw_sf_muon_id',
#        'syst_up_sf_muon_trigger', 'syst_dw_sf_muon_trigger',
#        'syst_up_sf_prefiring', 'syst_dw_sf_prefiring',
#        'syst_up_proton_scale_arm0', 'syst_dw_proton_scale_arm0',
#        'syst_up_proton_scale_arm1', 'syst_dw_proton_scale_arm1',
#        'syst_up_proton_scale', 'syst_dw_proton_scale', 'syst_up_proton_eff',
#        'syst_dw_proton_eff', 'syst_up_total', 'syst_dw_total', 'syst_bkg',
#        'syst_up_diss', 'syst_dw_diss'],
#       dtype='object')

# %%
df_sum_weights.columns
# Out:
# Index(['GGToWW-AQGC-2018-muon-ACW5e-7', 'GGToWW-AQGC-2018-muon-ACW1e-6',
#        'GGToWW-AQGC-2018-muon-ACW2e-6', 'GGToWW-AQGC-2018-muon-ACW5e-6',
#        'GGToWW-AQGC-2018-muon-ACW1e-5', 'GGToWW-AQGC-2018-muon-ACW2e-5',
#        'Background'],
#       dtype='object')

# %%
df_sum_weights = df_sum_weights.drop(columns='Background')

# %%
df_sum_weights.iloc[ 1:, : ].where( ~( df_sum_weights.iloc[ 1:, : ] != -1. ) , df_sum_weights.iloc[ 1:, : ].divide( df_sum_weights.iloc[ 0 ] ) * 100. )
# Out:
#                            GGToWW-AQGC-2018-muon-ACW5e-7  \
# stat                                           10.142445
# syst_up_jes                                     4.566130
# syst_dw_jes                                    -4.566130
# syst_up_jer                                     1.177908
# syst_dw_jer                                    -1.177908
# syst_up_sf_muon_id                              0.053039
# syst_dw_sf_muon_id                             -0.053039
# syst_up_sf_muon_trigger                         0.192830
# syst_dw_sf_muon_trigger                        -0.192830
# syst_up_sf_prefiring                            0.128494
# syst_dw_sf_prefiring                           -0.128494
# syst_up_proton_scale_arm0                       2.946807
# syst_dw_proton_scale_arm0                      -9.851509
# syst_up_proton_scale_arm1                       7.132986
# syst_dw_proton_scale_arm1                      -3.969322
# ...

# %%
percent_ = False
precision_ = 2
debug_ = False
# labels_samples_ = {
#     "GGToWW-AQGC-A0W1e-6": r"$\gamma\gamma \to WW \quad a_0^W/\Lambda^2 = 1 \times 10^{-6} \,\rm{GeV}^{-2}$",
#     "GGToWW-AQGC-A0W2e-6": r"$\gamma\gamma \to WW \quad a_0^W/\Lambda^2 = 2 \times 10^{-6} \,\rm{GeV}^{-2}$",
#     "GGToWW-AQGC-A0W5e-6": r"$\gamma\gamma \to WW \quad a_0^W/\Lambda^2 = 5 \times 10^{-6} \,\rm{GeV}^{-2}$"
# }
labels_samples_ = {
#     "GGToWW-AQGC-A0W1e-6": r"$a_0^W/\Lambda^2 = 1 \times 10^{-6} \,\rm{GeV}^{-2}$",
#     "GGToWW-AQGC-A0W2e-6": r"$a_0^W/\Lambda^2 = 2 \times 10^{-6} \,\rm{GeV}^{-2}$",
#     "GGToWW-AQGC-A0W5e-6": r"$a_0^W/\Lambda^2 = 5 \times 10^{-6} \,\rm{GeV}^{-2}$",
#     "GGToWW-AQGC-A0W1e-7": r"$a_0^W/\Lambda^2 = 1 \times 10^{-7} \,\rm{GeV}^{-2}$",
#     "GGToWW-AQGC-A0W2e-7": r"$a_0^W/\Lambda^2 = 2 \times 10^{-7} \,\rm{GeV}^{-2}$",
#     "GGToWW-AQGC-A0W5e-7": r"$a_0^W/\Lambda^2 = 5 \times 10^{-7} \,\rm{GeV}^{-2}$"
    "GGToWW-AQGC-A0W1e-6": r"$1 \times 10^{-6}$",
    "GGToWW-AQGC-A0W2e-6": r"$2 \times 10^{-6}$",
    "GGToWW-AQGC-A0W5e-6": r"$5 \times 10^{-6}$",
    "GGToWW-AQGC-A0W1e-7": r"$1 \times 10^{-7}$",
    "GGToWW-AQGC-A0W2e-7": r"$2 \times 10^{-7}$",
    "GGToWW-AQGC-A0W5e-7": r"$5 \times 10^{-7}$",
    "GGToWW-AQGC-ACW1e-5": r"$1 \times 10^{-5}$",
    "GGToWW-AQGC-ACW2e-5": r"$2 \times 10^{-5}$",
    "GGToWW-AQGC-ACW1e-6": r"$1 \times 10^{-6}$",
    "GGToWW-AQGC-ACW2e-6": r"$2 \times 10^{-6}$",
    "GGToWW-AQGC-ACW5e-6": r"$5 \times 10^{-6}$",
    "GGToWW-AQGC-ACW5e-7": r"$5 \times 10^{-7}$"

}
labels_samples_[ "GGToWW-AQGC-muon-A0W1e-6" ] = labels_samples_[ "GGToWW-AQGC-A0W1e-6" ]
labels_samples_[ "GGToWW-AQGC-muon-A0W2e-6" ] = labels_samples_[ "GGToWW-AQGC-A0W2e-6" ]
labels_samples_[ "GGToWW-AQGC-muon-A0W5e-6" ] = labels_samples_[ "GGToWW-AQGC-A0W5e-6" ]
labels_samples_[ "GGToWW-AQGC-muon-A0W1e-7" ] = labels_samples_[ "GGToWW-AQGC-A0W1e-7" ]
labels_samples_[ "GGToWW-AQGC-muon-A0W2e-7" ] = labels_samples_[ "GGToWW-AQGC-A0W2e-7" ]
labels_samples_[ "GGToWW-AQGC-muon-A0W5e-7" ] = labels_samples_[ "GGToWW-AQGC-A0W5e-7" ]
labels_samples_[ "GGToWW-AQGC-muon-ACW1e-5" ] = labels_samples_[ "GGToWW-AQGC-ACW1e-5" ]
labels_samples_[ "GGToWW-AQGC-muon-ACW2e-5" ] = labels_samples_[ "GGToWW-AQGC-ACW2e-5" ]
labels_samples_[ "GGToWW-AQGC-muon-ACW1e-6" ] = labels_samples_[ "GGToWW-AQGC-ACW1e-6" ]
labels_samples_[ "GGToWW-AQGC-muon-ACW2e-6" ] = labels_samples_[ "GGToWW-AQGC-ACW2e-6" ]
labels_samples_[ "GGToWW-AQGC-muon-ACW5e-6" ] = labels_samples_[ "GGToWW-AQGC-ACW5e-6" ]
labels_samples_[ "GGToWW-AQGC-muon-ACW5e-7" ] = labels_samples_[ "GGToWW-AQGC-ACW5e-7" ]
labels_samples_[ "GGToWW-AQGC-electron-A0W1e-6" ] = labels_samples_[ "GGToWW-AQGC-A0W1e-6" ]
labels_samples_[ "GGToWW-AQGC-electron-A0W2e-6" ] = labels_samples_[ "GGToWW-AQGC-A0W2e-6" ]
labels_samples_[ "GGToWW-AQGC-electron-A0W5e-6" ] = labels_samples_[ "GGToWW-AQGC-A0W5e-6" ]
labels_samples_[ "GGToWW-AQGC-electron-A0W1e-7" ] = labels_samples_[ "GGToWW-AQGC-A0W1e-7" ]
labels_samples_[ "GGToWW-AQGC-electron-A0W2e-7" ] = labels_samples_[ "GGToWW-AQGC-A0W2e-7" ]
labels_samples_[ "GGToWW-AQGC-electron-A0W5e-7" ] = labels_samples_[ "GGToWW-AQGC-A0W5e-7" ]
labels_samples_[ "GGToWW-AQGC-electron-ACW1e-5" ] = labels_samples_[ "GGToWW-AQGC-ACW1e-5" ]
labels_samples_[ "GGToWW-AQGC-electron-ACW2e-5" ] = labels_samples_[ "GGToWW-AQGC-ACW2e-5" ]
labels_samples_[ "GGToWW-AQGC-electron-ACW1e-6" ] = labels_samples_[ "GGToWW-AQGC-ACW1e-6" ]
labels_samples_[ "GGToWW-AQGC-electron-ACW2e-6" ] = labels_samples_[ "GGToWW-AQGC-ACW2e-6" ]
labels_samples_[ "GGToWW-AQGC-electron-ACW5e-6" ] = labels_samples_[ "GGToWW-AQGC-ACW5e-6" ]
labels_samples_[ "GGToWW-AQGC-electron-ACW5e-7" ] = labels_samples_[ "GGToWW-AQGC-ACW5e-7" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-A0W1e-6" ] = labels_samples_[ "GGToWW-AQGC-muon-A0W1e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-A0W2e-6" ] = labels_samples_[ "GGToWW-AQGC-muon-A0W2e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-A0W5e-6" ] = labels_samples_[ "GGToWW-AQGC-muon-A0W5e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-A0W1e-7" ] = labels_samples_[ "GGToWW-AQGC-muon-A0W1e-7" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-A0W2e-7" ] = labels_samples_[ "GGToWW-AQGC-muon-A0W2e-7" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-A0W5e-7" ] = labels_samples_[ "GGToWW-AQGC-muon-A0W5e-7" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-ACW1e-5" ] = labels_samples_[ "GGToWW-AQGC-muon-ACW1e-5" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-ACW2e-5" ] = labels_samples_[ "GGToWW-AQGC-muon-ACW2e-5" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-ACW1e-6" ] = labels_samples_[ "GGToWW-AQGC-muon-ACW1e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-ACW2e-6" ] = labels_samples_[ "GGToWW-AQGC-muon-ACW2e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-ACW5e-6" ] = labels_samples_[ "GGToWW-AQGC-muon-ACW5e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-muon-ACW5e-7" ] = labels_samples_[ "GGToWW-AQGC-muon-ACW5e-7" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-A0W1e-6" ] = labels_samples_[ "GGToWW-AQGC-electron-A0W1e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-A0W2e-6" ] = labels_samples_[ "GGToWW-AQGC-electron-A0W2e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-A0W5e-6" ] = labels_samples_[ "GGToWW-AQGC-electron-A0W5e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-A0W1e-7" ] = labels_samples_[ "GGToWW-AQGC-electron-A0W1e-7" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-A0W2e-7" ] = labels_samples_[ "GGToWW-AQGC-electron-A0W2e-7" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-A0W5e-7" ] = labels_samples_[ "GGToWW-AQGC-electron-A0W5e-7" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-ACW1e-5" ] = labels_samples_[ "GGToWW-AQGC-electron-ACW1e-5" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-ACW2e-5" ] = labels_samples_[ "GGToWW-AQGC-electron-ACW2e-5" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-ACW1e-6" ] = labels_samples_[ "GGToWW-AQGC-electron-ACW1e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-ACW2e-6" ] = labels_samples_[ "GGToWW-AQGC-electron-ACW2e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-ACW5e-6" ] = labels_samples_[ "GGToWW-AQGC-electron-ACW5e-6" ]
labels_samples_[ "GGToWW-AQGC-2018-electron-ACW5e-7" ] = labels_samples_[ "GGToWW-AQGC-electron-ACW5e-7" ]


# labels_samples_[ "Background" ] = "Background"
index_names_ = {
    'central': 'Central value',
    'stat': 'Statistical',
    'jes': 'Jet energy scale',
    'jer': 'Jet energy resolution',
    'sf_muon_id': 'Muon ID',
    'sf_electron_id': 'Electron ID',
    'sf_muon_trigger': 'Muon trigger', 
    'sf_electron_trigger': 'Electron trigger',
    'sf_prefiring': 'Prefiring', 
    'proton_scale': 'Proton momentum scale',
    'proton_eff': 'Proton efficiency',
    'background': 'Background',
    'total': 'Total (experimental)',
    'diss': 'Proton dissociation (model)'
}
df__ = df_sum_weights
if percent_: df__ = df__.iloc[ 1:, : ].where( ~( df__.iloc[ 1:, : ] != -1. ) , df__.iloc[ 1:, : ].divide( df__.iloc[ 0 ] ) * 100. )
if percent_: precision_ = 1
columns_ = df__.columns.values
var_name_sf_lepton_id__ = ""
var_name_sf_lepton_trigger__ = ""
if lepton_type == 'muon':
    var_name_sf_lepton_id__ = 'sf_muon_id'
    var_name_sf_lepton_trigger__ = 'sf_muon_trigger'
elif lepton_type == 'electron':
    var_name_sf_lepton_id__ = 'sf_electron_id'
    var_name_sf_lepton_trigger__ = 'sf_electron_trigger'
systematics_list_ = [ 'jes', 'jer', var_name_sf_lepton_id__, var_name_sf_lepton_trigger__, 'sf_prefiring', 'proton_scale', 'proton_eff', 'total', 'diss' ]
line_str = r"\begin{table}"; print ( line_str )
line_str = r"\begin{{tabular}}{{|l | {}}} \hline".format( 'r | ' * len( columns_ ) ); print ( line_str )
if alpha == "a0w":
    line_str = r"\boldmath{$a_{0}^{W}/\Lambda^2\,\rm({GeV}^{-2})$}"+" & "
if alpha == "aCw":
    line_str = r"\boldmath{$a_{C}^{W}/\Lambda^2\,\rm({GeV}^{-2})$}"+" & "
for idx_, label_sample__ in enumerate( columns_ ):
    line_str += r"\boldmath{"
    line_str += labels_samples_[ label_sample__ ]
    if idx_ < ( len( columns_ ) - 1 ): line_str += "} & "
line_str += r"} \\ \hline"
print ( line_str )
if not percent_:
    for label__ in [ 'central' ]:
        line_str = "{:32}".format( index_names_[ label__ ] )
        line_str += " & "
        vals__ = df__.loc[ label__ ]
        for idx_, label_sample__ in enumerate( columns_ ):
            val__ = vals__.loc[ label_sample__ ]
            if debug_: print ( label__, label_sample__, val__ )
            line_str += "{:20}".format( r"{{:.{:d}f}}".format( precision_ ).format( val__ ) )
            if idx_ < ( len( columns_ ) - 1 ): line_str += " & "
        line_str += r" \\ \hline"
        print ( line_str )   
for label__ in [ 'stat' ]:
    line_str = "{:32}".format( index_names_[ label__ ] )
    line_str += " & "
    vals__ = df__.loc[ label__ ]
    for idx_, label_sample__ in enumerate( columns_ ):
        val__ = vals__.loc[ label_sample__ ]
        if debug_: print ( label__, label_sample__, val__ )
        if not percent_:
            line_str += "{:20}".format( r"$\pm${{:.{:d}f}}".format( precision_ ).format( val__ ) )
        else:
            line_str += "{:20}".format( r"$\pm${{:.{:d}f}}\%".format( precision_ ).format( val__ ) )
        if idx_ < ( len( columns_ ) - 1 ): line_str += " & "
    line_str += r" \\ \hline "
    print ( line_str )
for label_syst__ in systematics_list_:
    line_str = "{:32}".format( index_names_[ label_syst__ ] )
    line_str += " & "
    vals_up_label__ = 'syst_up_' + label_syst__
    vals_dw_label__ = 'syst_dw_' + label_syst__
    vals_up__ = df__.loc[ vals_up_label__ ]
    vals_dw__ = df__.loc[ vals_dw_label__ ]
    for idx_, label_sample__ in enumerate( columns_ ):
        if label_sample__ != 'Background':
            val_up__ = vals_up__.loc[ label_sample__ ]
            val_dw__ = vals_dw__.loc[ label_sample__ ]
            if debug_: print ( label_syst__, label_sample__, val_up__, val_dw__)
            if not percent_:
                if np.abs( val_up__ ) == np.abs( val_dw__ ):
                    line_str += "{:20}".format( r"$\pm${}".format( r"{{:.{:d}f}}".format( precision_ ).format( val_up__ ) ) )
                else:
                    line_str += "{:20}".format( r"$^{{{}}}_{{{}}}$".format( r"{{:+.{:d}f}}".format( precision_ ).format( val_up__ ),
                                                                            r"{{:-.{:d}f}}".format( precision_ ).format( val_dw__ ) ) )
            else:
                if np.abs( val_up__ ) == np.abs( val_dw__ ):
                    line_str += "{:20}".format( r"$\pm${}\%".format( r"{{:.{:d}f}}".format( precision_ ).format( val_up__ ) ) )
                else:
                    line_str += "{:20}".format( r"$^{{{}}}_{{{}}}$\%".format( r"{{:+.{:d}f}}".format( precision_ ).format( val_up__ ),
                                                                              r"{{:-.{:d}f}}".format( precision_ ).format( val_dw__ ) ) )
        else:
#             line_str += "{:20}".format( "--" )
            line_str += ""

        if idx_ < ( len( columns_ ) - 1 ): line_str += " & "
    line_str += r" \\ \hline"
    print ( line_str )
line_str = r"\end{tabular}"; print ( line_str )
line_str = r"\end{table}"; print ( line_str )
# Out:
# \begin{table}
# \begin{tabular}{|l | r | r | r | r | r | r | } \hline
# \boldmath{$a_{C}^{W}/\Lambda^2\,\rm({GeV}^{-2})$} & \boldmath{$5 \times 10^{-7}$} & \boldmath{$1 \times 10^{-6}$} & \boldmath{$2 \times 10^{-6}$} & \boldmath{$5 \times 10^{-6}$} & \boldmath{$1 \times 10^{-5}$} & \boldmath{$2 \times 10^{-5}$} \\ \hline
# Central value                    & 0.92                 & 1.17                 & 2.60                 & 7.39                 & 26.88                & 111.88               \\ \hline
# Statistical                      & $\pm$0.09            & $\pm$0.11            & $\pm$0.16            & $\pm$0.29            & $\pm$0.68            & $\pm$2.11            \\ \hline
# Jet energy scale                 & $\pm$0.04            & $\pm$0.00            & $\pm$0.00            & $\pm$0.05            & $\pm$0.17            & $\pm$0.37            \\ \hline
# ...
