# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.22/06

# %%
# fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017B-Dilepton/190621_214052/0000/SlimmedNtuple_merged_0.root"
fileName_ = "/eos/user/a/antoniov/Workspace/analysis/data/PPS/GGToWW_bSM-A0W1e-6_13TeV-fpmc-herwig6-signal-proton-propagation-dilepton/200420_160422/0000/SlimmedNtuple_merged_0.root"
# fileName_ = "/eos/home-a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017B-withDilepton/0000/SlimmedNtuple_merged_0.root"

file_ = ROOT.TFile( fileName_ , "READ" )
data_ = file_.Get( "demo/SlimmedNtuple" )
data_.Print()
# Out:
# ******************************************************************************
# *Tree    :SlimmedNtuple: SlimmedNtuple                                          *
# *Entries :    34159 : Total =        50613503 bytes  File  Size =   19631155 *
# *        :          : Tree compression factor =   2.58                       *
# ******************************************************************************
# *Br    0 :muon_pt   : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551310 bytes  File Size  =     207797 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.65     *
# *............................................................................*
# *Br    1 :muon_eta  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551339 bytes  File Size  =     212136 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.60     *
# *............................................................................*
# *Br    2 :muon_phi  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551339 bytes  File Size  =     211589 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.60     *
# *............................................................................*
# *Br    3 :muon_px   : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551310 bytes  File Size  =     213048 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.58     *
# *............................................................................*
# *Br    4 :muon_py   : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551310 bytes  File Size  =     212894 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.59     *
# *............................................................................*
# *Br    5 :muon_pz   : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551310 bytes  File Size  =     213238 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.58     *
# *............................................................................*
# *Br    6 :muon_e    : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551281 bytes  File Size  =     207471 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.65     *
# *............................................................................*
# *Br    7 :muon_charge : vector<float>                                        *
# *Entries :    34159 : Total  Size=     551426 bytes  File Size  =     126821 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   4.34     *
# *............................................................................*
# *Br    8 :muon_iso  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551339 bytes  File Size  =     158677 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   3.47     *
# *............................................................................*
# *Br    9 :muon_dxy  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551339 bytes  File Size  =     209490 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.63     *
# *............................................................................*
# *Br   10 :muon_dz   : vector<float>                                          *
# *Entries :    34159 : Total  Size=     551310 bytes  File Size  =     210327 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.62     *
# *............................................................................*
# *Br   11 :electron_pt : vector<float>                                        *
# *Entries :    34159 : Total  Size=     548090 bytes  File Size  =     204021 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.68     *
# *............................................................................*
# *Br   12 :electron_eta : vector<float>                                       *
# *Entries :    34159 : Total  Size=     548119 bytes  File Size  =     208074 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.63     *
# *............................................................................*
# *Br   13 :electron_phi : vector<float>                                       *
# *Entries :    34159 : Total  Size=     548119 bytes  File Size  =     207865 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.63     *
# *............................................................................*
# *Br   14 :electron_dxy : vector<float>                                       *
# *Entries :    34159 : Total  Size=     548119 bytes  File Size  =     205373 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.66     *
# *............................................................................*
# *Br   15 :electron_dz : vector<float>                                        *
# *Entries :    34159 : Total  Size=     548090 bytes  File Size  =     206641 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.65     *
# *............................................................................*
# *Br   16 :electron_px : vector<float>                                        *
# *Entries :    34159 : Total  Size=     548090 bytes  File Size  =     208897 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.62     *
# *............................................................................*
# *Br   17 :electron_py : vector<float>                                        *
# *Entries :    34159 : Total  Size=     548090 bytes  File Size  =     208970 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.62     *
# *............................................................................*
# *Br   18 :electron_pz : vector<float>                                        *
# *Entries :    34159 : Total  Size=     548090 bytes  File Size  =     209116 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.62     *
# *............................................................................*
# *Br   19 :electron_e : vector<float>                                         *
# *Entries :    34159 : Total  Size=     548061 bytes  File Size  =     203719 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.69     *
# *............................................................................*
# *Br   20 :electron_charge : vector<float>                                    *
# *Entries :    34159 : Total  Size=     548206 bytes  File Size  =     126474 *
# *Baskets :       25 : Basket Size=      32000 bytes  Compression=   4.33     *
# *............................................................................*
# *Br   21 :met       : met/f                                                  *
# *Entries :    34159 : Total  Size=     137666 bytes  File Size  =     124065 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br   22 :met_x     : met_x/f                                                *
# *Entries :    34159 : Total  Size=     137688 bytes  File Size  =     128737 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   23 :met_y     : met_y/f                                                *
# *Entries :    34159 : Total  Size=     137688 bytes  File Size  =     128758 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   24 :met_phi   : met_phi/f                                              *
# *Entries :    34159 : Total  Size=     137710 bytes  File Size  =     126882 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   25 :pfcand_nextracks : pfcand_nextracks/I                              *
# *Entries :    34159 : Total  Size=     137809 bytes  File Size  =      31288 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   4.39     *
# *............................................................................*
# *Br   26 :pfcand_nextracks_noDRl : pfcand_nextracks_noDRl/I                  *
# *Entries :    34159 : Total  Size=     137875 bytes  File Size  =      31401 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   4.37     *
# *............................................................................*
# *Br   27 :num_bjets_ak8 : num_bjets_ak8/I                                    *
# *Entries :    34159 : Total  Size=     137776 bytes  File Size  =       3496 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  39.26     *
# *............................................................................*
# *Br   28 :num_bjets_ak4 : num_bjets_ak4/I                                    *
# *Entries :    34159 : Total  Size=     137776 bytes  File Size  =       1496 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  91.75     *
# *............................................................................*
# *Br   29 :num_jets_ak4 : num_jets_ak4/I                                      *
# *Entries :    34159 : Total  Size=     137765 bytes  File Size  =       9697 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  14.15     *
# *............................................................................*
# *Br   30 :recoMWhad : recoMWhad/f                                            *
# *Entries :    34159 : Total  Size=     137732 bytes  File Size  =     119633 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.15     *
# *............................................................................*
# *Br   31 :recoMWlep : recoMWlep/f                                            *
# *Entries :    34159 : Total  Size=     137732 bytes  File Size  =      72530 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.89     *
# *............................................................................*
# *Br   32 :recoMWW   : recoMWW/f                                              *
# *Entries :    34159 : Total  Size=     137710 bytes  File Size  =     120902 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   33 :recoRapidityWW : recoRapidityWW/f                                  *
# *Entries :    34159 : Total  Size=     137787 bytes  File Size  =     128218 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   34 :recoWWpt  : recoWWpt_/f                                            *
# *Entries :    34159 : Total  Size=     137724 bytes  File Size  =     123807 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br   35 :genWWpt   : genWWpt_/f                                             *
# *Entries :    34159 : Total  Size=     137713 bytes  File Size  =       1404 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  97.73     *
# *............................................................................*
# *Br   36 :dphiWW    : dphiWW/f                                               *
# *Entries :    34159 : Total  Size=     137699 bytes  File Size  =     106787 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   37 :WLeptonicPt : WLeptonicPt/f                                        *
# *Entries :    34159 : Total  Size=     137754 bytes  File Size  =     121226 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   38 :WLeptonicPhi : WLeptonicPhi/f                                      *
# *Entries :    34159 : Total  Size=     137765 bytes  File Size  =     126992 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   39 :WLeptonicEta : WLeptonicEta/f                                      *
# *Entries :    34159 : Total  Size=     137765 bytes  File Size  =     127740 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.07     *
# *............................................................................*
# *Br   40 :jet_pt    : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618255 bytes  File Size  =     256822 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.40     *
# *............................................................................*
# *Br   41 :jet_px    : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618255 bytes  File Size  =     267869 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br   42 :jet_py    : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618255 bytes  File Size  =     267917 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br   43 :jet_pz    : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618255 bytes  File Size  =     268560 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br   44 :jet_energy : vector<float>                                         *
# *Entries :    34159 : Total  Size=     618383 bytes  File Size  =     253944 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.43     *
# *............................................................................*
# *Br   45 :jet_phi   : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618287 bytes  File Size  =     267183 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.31     *
# *............................................................................*
# *Br   46 :jet_eta   : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618287 bytes  File Size  =     267557 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.31     *
# *............................................................................*
# *Br   47 :jet_mass  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618319 bytes  File Size  =     254897 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.42     *
# *............................................................................*
# *Br   48 :jet_tau1  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618319 bytes  File Size  =     257358 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.40     *
# *............................................................................*
# *Br   49 :jet_tau2  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     618319 bytes  File Size  =     254406 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.43     *
# *............................................................................*
# *Br   50 :jet_corrmass : vector<float>                                       *
# *Entries :    34159 : Total  Size=     618447 bytes  File Size  =     254914 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.42     *
# *............................................................................*
# *Br   51 :jet_vertexz : vector<float>                                        *
# *Entries :    34159 : Total  Size=     618415 bytes  File Size  =      88096 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   7.01     *
# *............................................................................*
# *Br   52 :jet_jer_res : vector<float>                                        *
# *Entries :    34159 : Total  Size=     739716 bytes  File Size  =     372111 *
# *Baskets :       31 : Basket Size=      32000 bytes  Compression=   1.99     *
# *............................................................................*
# *Br   53 :jet_jer_sf : vector<float>                                         *
# *Entries :    34159 : Total  Size=     739681 bytes  File Size  =     177811 *
# *Baskets :       31 : Basket Size=      32000 bytes  Compression=   4.15     *
# *............................................................................*
# *Br   54 :jet_jer_sfup : vector<float>                                       *
# *Entries :    34159 : Total  Size=     739751 bytes  File Size  =     178617 *
# *Baskets :       31 : Basket Size=      32000 bytes  Compression=   4.14     *
# *............................................................................*
# *Br   55 :jet_jer_sfdown : vector<float>                                     *
# *Entries :    34159 : Total  Size=     739821 bytes  File Size  =     178785 *
# *Baskets :       31 : Basket Size=      32000 bytes  Compression=   4.13     *
# *............................................................................*
# *Br   56 :pps_track_x : vector<float>                                        *
# *Entries :    34159 : Total  Size=     766011 bytes  File Size  =     344820 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   2.22     *
# *............................................................................*
# *Br   57 :pps_track_y : vector<float>                                        *
# *Entries :    34159 : Total  Size=     766011 bytes  File Size  =     340271 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   2.25     *
# *............................................................................*
# *Br   58 :pps_track_rpid : vector<int>                                       *
# *Entries :    34159 : Total  Size=     766119 bytes  File Size  =     160424 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   4.77     *
# *............................................................................*
# *Br   59 :hlt       : vector<string>                                         *
# *Entries :    34159 : Total  Size=     480988 bytes  File Size  =      85265 *
# *Baskets :       23 : Basket Size=      32000 bytes  Compression=   5.63     *
# *............................................................................*
# *Br   60 :gen_W_pt  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     481123 bytes  File Size  =      85285 *
# *Baskets :       23 : Basket Size=      32000 bytes  Compression=   5.63     *
# *............................................................................*
# *Br   61 :gen_W_charge : vector<float>                                       *
# *Entries :    34159 : Total  Size=     481231 bytes  File Size  =      85291 *
# *Baskets :       23 : Basket Size=      32000 bytes  Compression=   5.63     *
# *............................................................................*
# *Br   62 :gen_proton_px : vector<float>                                      *
# *Entries :    34159 : Total  Size=     755591 bytes  File Size  =     407391 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   1.85     *
# *............................................................................*
# *Br   63 :gen_proton_py : vector<float>                                      *
# *Entries :    34159 : Total  Size=     755591 bytes  File Size  =     407507 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   1.85     *
# *............................................................................*
# *Br   64 :gen_proton_pz : vector<float>                                      *
# *Entries :    34159 : Total  Size=     755591 bytes  File Size  =     371811 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   2.03     *
# *............................................................................*
# *Br   65 :gen_proton_energy : vector<float>                                  *
# *Entries :    34159 : Total  Size=     755735 bytes  File Size  =     372404 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   2.03     *
# *............................................................................*
# *Br   66 :gen_proton_xi : vector<float>                                      *
# *Entries :    34159 : Total  Size=     755591 bytes  File Size  =     392222 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   1.92     *
# *............................................................................*
# *Br   67 :gen_proton_t : vector<float>                                       *
# *Entries :    34159 : Total  Size=     755555 bytes  File Size  =     400350 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   1.88     *
# *............................................................................*
# *Br   68 :proton_xi : vector<float>                                          *
# *Entries :    34159 : Total  Size=     897083 bytes  File Size  =     541506 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   1.65     *
# *............................................................................*
# *Br   69 :proton_thx : vector<float>                                         *
# *Entries :    34159 : Total  Size=     897123 bytes  File Size  =     305334 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   2.93     *
# *............................................................................*
# *Br   70 :proton_thy : vector<float>                                         *
# *Entries :    34159 : Total  Size=     897123 bytes  File Size  =     572121 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   1.57     *
# *............................................................................*
# *Br   71 :proton_t  : vector<float>                                          *
# *Entries :    34159 : Total  Size=     897043 bytes  File Size  =     568320 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   1.58     *
# *............................................................................*
# *Br   72 :proton_ismultirp_ : vector<int>                                    *
# *Entries :    34159 : Total  Size=     897403 bytes  File Size  =     144396 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   6.21     *
# *............................................................................*
# *Br   73 :proton_rpid : vector<int>                                          *
# *Entries :    34159 : Total  Size=     897163 bytes  File Size  =     166302 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   5.39     *
# *............................................................................*
# *Br   74 :proton_arm : vector<int>                                           *
# *Entries :    34159 : Total  Size=     897123 bytes  File Size  =     155964 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   5.75     *
# *............................................................................*
# *Br   75 :proton_time : vector<float>                                        *
# *Entries :    34159 : Total  Size=     897163 bytes  File Size  =     143956 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   6.22     *
# *............................................................................*
# *Br   76 :proton_trackx1 : vector<float>                                     *
# *Entries :    34159 : Total  Size=     897283 bytes  File Size  =     415500 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   2.16     *
# *............................................................................*
# *Br   77 :proton_tracky1 : vector<float>                                     *
# *Entries :    34159 : Total  Size=     897283 bytes  File Size  =     411727 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   2.18     *
# *............................................................................*
# *Br   78 :proton_trackx2 : vector<float>                                     *
# *Entries :    34159 : Total  Size=     612567 bytes  File Size  =     224877 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.72     *
# *............................................................................*
# *Br   79 :proton_tracky2 : vector<float>                                     *
# *Entries :    34159 : Total  Size=     612567 bytes  File Size  =     209952 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   2.91     *
# *............................................................................*
# *Br   80 :proton_trackpixshift1 : vector<int>                                *
# *Entries :    34159 : Total  Size=     897563 bytes  File Size  =     144324 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   6.21     *
# *............................................................................*
# *Br   81 :proton_trackpixshift2 : vector<int>                                *
# *Entries :    34159 : Total  Size=     612791 bytes  File Size  =     128265 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   4.77     *
# *............................................................................*
# *Br   82 :proton_rpid1 : vector<int>                                         *
# *Entries :    34159 : Total  Size=     897203 bytes  File Size  =     166249 *
# *Baskets :       36 : Basket Size=      32000 bytes  Compression=   5.39     *
# *............................................................................*
# *Br   83 :proton_rpid2 : vector<int>                                         *
# *Entries :    34159 : Total  Size=     612503 bytes  File Size  =     137920 *
# *Baskets :       28 : Basket Size=      32000 bytes  Compression=   4.43     *
# *............................................................................*
# *Br   84 :gen_jet_pt : vector<float>                                         *
# *Entries :    34159 : Total  Size=     765279 bytes  File Size  =     409456 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   1.87     *
# *............................................................................*
# *Br   85 :gen_jet_phi : vector<float>                                        *
# *Entries :    34159 : Total  Size=     765315 bytes  File Size  =     422600 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   1.81     *
# *............................................................................*
# *Br   86 :gen_jet_eta : vector<float>                                        *
# *Entries :    34159 : Total  Size=     765315 bytes  File Size  =     423467 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   1.80     *
# *............................................................................*
# *Br   87 :gen_jet_energy : vector<float>                                     *
# *Entries :    34159 : Total  Size=     765423 bytes  File Size  =     407229 *
# *Baskets :       32 : Basket Size=      32000 bytes  Compression=   1.88     *
# *............................................................................*
# *Br   88 :nVertices : nVertices/i                                            *
# *Entries :    34159 : Total  Size=     137732 bytes  File Size  =      42600 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   3.22     *
# *............................................................................*
# *Br   89 :pileupWeight : pileupWeight/f                                      *
# *Entries :    34159 : Total  Size=     137765 bytes  File Size  =      50035 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   2.74     *
# *............................................................................*
# *Br   90 :mc_pu_trueinteractions : mc_pu_trueinteractions/f                  *
# *Entries :    34159 : Total  Size=     137875 bytes  File Size  =     121506 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   1.13     *
# *............................................................................*
# *Br   91 :mcWeight  : mcWeight/f                                             *
# *Entries :    34159 : Total  Size=     137721 bytes  File Size  =       1501 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  91.42     *
# *............................................................................*
# *Br   92 :run       : run/I                                                  *
# *Entries :    34159 : Total  Size=     137666 bytes  File Size  =       1467 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  93.52     *
# *............................................................................*
# *Br   93 :event     : event/L                                                *
# *Entries :    34159 : Total  Size=     274696 bytes  File Size  =     113165 *
# *Baskets :       11 : Basket Size=      32000 bytes  Compression=   2.42     *
# *............................................................................*
# *Br   94 :lumiblock : lumiblock/I                                            *
# *Entries :    34159 : Total  Size=     137732 bytes  File Size  =      29469 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   4.66     *
# *............................................................................*
# *Br   95 :crossingAngle : crossingAngle/f                                    *
# *Entries :    34159 : Total  Size=     137776 bytes  File Size  =      17616 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=   7.79     *
# *............................................................................*
# *Br   96 :betaStar  : betaStar/f                                             *
# *Entries :    34159 : Total  Size=     137721 bytes  File Size  =       1523 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  90.10     *
# *............................................................................*
# *Br   97 :instLumi  : instLumi/f                                             *
# *Entries :    34159 : Total  Size=     137721 bytes  File Size  =       1411 *
# *Baskets :        7 : Basket Size=      32000 bytes  Compression=  97.25     *
# *............................................................................*

# %%
#chain_ = ROOT.TChain( "demo/SlimmedNtuple" )
#chain_.Add( "/eos/user/a/antoniov/Workspace/analysis/data/PPS/SingleMuon-Run2017B-Dilepton/190621_214052/0000/SlimmedNtuple_*.root" )

# %%
#chain_.Print()

# %%
"""
NJETMAX = 30
jet_pt_ = ROOT.std.vector('float')(NJETMAX)
chain_.SetBranchAddress( 'jet_pt', jet_pt_ )
NMUMAX = 30
muon_pt_ = ROOT.std.vector('float')(NMUMAX)
chain_.SetBranchAddress( 'muon_pt', muon_pt_ )
print( jet_pt_.size() )
print( muon_pt_.size() )
"""

# %%
"""
#for ientry in range( data_.GetEntriesFast() ):
for ientry in range( 50 ):
    chain_.GetEntry( ientry )
    print( muon_pt_ )
"""

# %%
data_.GetEntry(10)
print ( data_.hlt )
print ( data_.jet_pt.size() )
print ( data_.jet_pt )
print ( data_.jet_eta )
print ( data_.jet_phi )
print ( data_.jet_vertexz ) 
print ( data_.jet_jer_res )
print ( data_.jet_jer_sf )
print ( data_.jet_jer_sfup )
print ( data_.jet_jer_sfdown )
print ( data_.muon_pt.size() )
print ( data_.muon_pt )
print ( data_.muon_eta )
print ( data_.muon_phi )
print ( data_.muon_charge )
print ( data_.muon_dxy )
print ( data_.muon_dz )
print ( data_.num_bjets_ak8 )
print ( data_.num_bjets_ak4 )
print ( data_.num_jets_ak4 )
print ( data_.recoMWhad )
print ( data_.recoMWlep )
print ( data_.recoMWW )
print ( data_.recoRapidityWW )
print ( data_.dphiWW )
print ( data_.WLeptonicPt )
print ( data_.WLeptonicPhi )
print ( data_.pfcand_nextracks )
print ( data_.pfcand_nextracks_noDRl )
print ( data_.proton_xi )
print ( data_.proton_ismultirp_ )
print ( data_.proton_rpid )
print ( data_.proton_arm )
print ( data_.proton_thx )
print ( data_.proton_thy )
print ( data_.proton_trackx1 )
print ( data_.proton_tracky1 )
print ( data_.proton_trackx2 )
print ( data_.proton_tracky2 )
print ( data_.proton_trackpixshift1 )
print ( data_.proton_trackpixshift2 )
print ( data_.proton_rpid1 )
print ( data_.proton_rpid2 )
print ( data_.pps_track_x )
print ( data_.pps_track_y )
print ( data_.pps_track_rpid )

# %%
maxEvents_ = 10
for idx, entry in enumerate( data_ ):
    if idx >= maxEvents_: break
    print ( "\n{}, {}, {}".format( entry.run, entry.event, entry.lumiblock ) )
    print ( entry.hlt.size() )
    print ( entry.hlt )
    print ( entry.jet_pt.size() )
    print ( "{}, {}, {}".format( entry.jet_pt.at(0), entry.jet_eta.at(0), entry.jet_phi.at(0) ) )
    print ( "{}, {}".format( entry.jet_tau1.at(0), entry.jet_tau2.at(0) ) )
    print ( "{}, {}".format( entry.jet_mass.at(0), entry.jet_corrmass.at(0) ) )
    print ( entry.muon_pt.size() )
    print ( entry.muon_pt )
    print ( entry.proton_xi.size() )
    print ( entry.proton_xi )
    print ( entry.proton_ismultirp_ )
    print ( entry.proton_rpid )
    print ( entry.proton_arm )
    print ( entry.pps_track_x )
    print ( entry.pps_track_y )
    print ( entry.pps_track_rpid )
